# %%
import pickle

# %%
with open("/Users/xbh0403/Desktop/TWAS_ASSOC/models/results/elasticnet_results.pkl", "rb") as f:
    enet = pickle.load(f)

# %%
train_r2 = [enet[k]["r2_train"] for k in enet]
test_r2 = [enet[k]["r2_test"] for k in enet]

# %%
# density plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(train_r2, label="train")
sns.kdeplot(test_r2, label="test")
# Out:
# <Axes: ylabel='Density'>

# %%
with open("/Users/xbh0403/Desktop/TWAS_ASSOC/models/results/lasso_results.pkl", "rb") as f:
    lasso = pickle.load(f)

# %%
train_r2 = [lasso[k]["r2_train"] for k in lasso]
test_r2 = [lasso[k]["r2_test"] for k in lasso]

# %%
lasso["ENSG00000187642"]["X_train"].shape
# Out:
# (71, 138)

# %%
# density plot
sns.kdeplot(train_r2, label="train")
sns.kdeplot(test_r2, label="test")
# Out:
# <Axes: ylabel='Density'>
